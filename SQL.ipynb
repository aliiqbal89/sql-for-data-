# %%
import sqlite3

conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# Create tables (department first since employees references it)
cursor.execute('''
    CREATE TABLE department (
        dept_id INTEGER PRIMARY KEY,
        dept_name TEXT
    )
''')

cursor.execute('''
    CREATE TABLE employees (
        emp_id INTEGER PRIMARY KEY,
        emp_name TEXT,
        dept_id INTEGER,
        salary INTEGER,
        gender TEXT,
        join_date DATE,
        FOREIGN KEY(dept_id) REFERENCES department(dept_id)
    )
''')

cursor.execute('''
    CREATE TABLE projects (
        project_id INTEGER PRIMARY KEY,
        project_name TEXT,
        project_budget INTEGER,
        start_date DATE,
        end_date DATE,
        status TEXT
    )
''')

cursor.execute('''
    CREATE TABLE employee_projects (
        emp_id INTEGER,
        project_id INTEGER,
        project_role TEXT,
        hours_worked INTEGER,
        assignment_date DATE,
        FOREIGN KEY(emp_id) REFERENCES employees(emp_id),
        FOREIGN KEY(project_id) REFERENCES projects(project_id)
    )
''')

# Insert departments
cursor.executemany('''
    INSERT INTO department (dept_id, dept_name) VALUES (?, ?)
''', [
    (101, 'HR'),
    (102, 'IT'),
    (103, 'Finance'),
    (104, 'Sales'),
    (105, 'Finance'),
    (106, 'Marketing'),
    (107, 'Operations'),
    (108, 'Research & Development'),
    (109, 'Customer Support'),
    (110, 'Quality Assurance')
])

# Insert employees (all fields now included)
cursor.executemany('''
    INSERT INTO employees (emp_id, emp_name, dept_id, salary, gender, join_date)
    VALUES (?, ?, ?, ?, ?, ?)
''', [
    (1, 'Ali', 101, 5000, 'M', '2021-05-01'),
    (2, 'Mohd', 102, 6000, 'M', '2020-03-15'),
    (3, 'Rahul', 103, 5500, 'M', '2022-01-10'),
    (4, 'Raj', None, 4500, 'M', '2021-11-22'),
    (5, 'Ahmed', 105, 6500, 'M', '2020-07-30'),
    (6, 'Sneha', 104, 5200, 'F', '2022-02-18'),
    (7, 'John', 106, 7000, 'M', '2019-09-05'),
    (8, 'Priya', 108, 5800, 'F', '2021-08-12'),
    (9, 'David', 102, 6200, 'M', '2020-11-30'),
    (10, 'Anjali', 109, 4800, 'F', '2022-03-25'),
    (11, 'Michael', 110, 5300, 'M', '2021-07-14'),
    (12, 'Sophia', 107, 5900, 'F', '2020-05-20'),
    (13, 'Robert', 103, 6700, 'M', '2019-12-05'),
    (14, 'Emma', 106, 5400, 'F', '2022-01-15'),
    (15, 'Daniel', 108, 7100, 'M', '2020-09-10')
])

# Insert projects (all fields now included)
cursor.executemany('''
    INSERT INTO projects (project_id, project_name, project_budget, start_date, end_date, status)
    VALUES (?, ?, ?, ?, ?, ?)
''', [
    (201, 'Project Alpha', 100000, '2023-01-15', '2023-06-30', 'Completed'),
    (202, 'Project Beta', 150000, '2023-03-01', '2023-08-15', 'In Progress'),
    (203, 'Project Gamma', 80000, '2023-02-10', '2023-05-20', 'Completed'),
    (204, 'Project Delta', 120000, '2023-04-05', '2023-09-30', 'In Progress'),
    (205, 'Project Epsilon', 90000, '2023-05-15', '2023-10-10', 'In Progress'),
    (206, 'Project Zeta', 75000, '2023-06-01', '2023-11-15', 'Not Started'),
    (207, 'Project Omega', 200000, '2023-07-10', '2024-01-20', 'Not Started')
])

# Insert employee_projects (all fields now included)
cursor.executemany('''
    INSERT INTO employee_projects (emp_id, project_id, project_role, hours_worked, assignment_date)
    VALUES (?, ?, ?, ?, ?)
''', [
    (1, 201, 'Manager', 120, '2023-01-10'),
    (2, 201, 'Developer', 180, '2023-01-10'),
    (7, 201, 'Developer', 140, '2023-01-15'),
    (9, 201, 'QA Engineer', 90, '2023-01-20'),
    (12, 201, 'Business Analyst', 75, '2023-01-12'),
    (3, 202, 'Analyst', 150, '2023-02-25'),
    (4, 202, 'Developer', 200, '2023-02-25'),
    (8, 202, 'UI Designer', 110, '2023-03-01'),
    (13, 202, 'Finance Consultant', 60, '2023-03-05'),
    (15, 202, 'Tech Lead', 180, '2023-02-28'),
    (5, 203, 'Manager', 90, '2023-02-05'),
    (6, 203, 'Designer', 160, '2023-02-05'),
    (10, 203, 'Tester', 85, '2023-02-15'),
    (11, 203, 'QA Lead', 95, '2023-02-10'),
    (2, 204, 'Senior Developer', 200, '2023-04-01'),
    (7, 204, 'Project Manager', 150, '2023-04-01'),
    (9, 204, 'Architect', 180, '2023-04-05'),
    (14, 204, 'Marketing Specialist', 70, '2023-04-10'),
    (1, 205, 'HR Consultant', 60, '2023-05-10'),
    (3, 205, 'Financial Analyst', 120, '2023-05-10'),
    (5, 205, 'Coordinator', 100, '2023-05-15'),
    (12, 205, 'Operations Manager', 130, '2023-05-12'),
    (4, 206, 'Developer', 0, '2023-05-30'),
    (6, 206, 'Designer', 0, '2023-05-30'),
    (8, 206, 'UI Specialist', 0, '2023-06-01'),
    (10, 207, 'Support Lead', 0, '2023-06-15'),
    (11, 207, 'QA Manager', 0, '2023-06-15'),
    (13, 207, 'Finance Lead', 0, '2023-06-20'),
    (15, 207, 'Technical Director', 0, '2023-06-18')
])

conn.commit()

# %%
import pandas as pd

query = "SELECT * FROM projects"

df = pd.read_sql_query(query, conn)
df
# Out:
#    project_id     project_name  project_budget  start_date    end_date  \
# 0         201    Project Alpha          100000  2023-01-15  2023-06-30
# 1         202     Project Beta          150000  2023-03-01  2023-08-15
# 2         203    Project Gamma           80000  2023-02-10  2023-05-20
# 3         204    Project Delta          120000  2023-04-05  2023-09-30
# 4         205  Project Epsilon           90000  2023-05-15  2023-10-10
# 5         206     Project Zeta           75000  2023-06-01  2023-11-15
# 6         207    Project Omega          200000  2023-07-10  2024-01-20
#
#         status
# 0    Completed
# 1  In Progress
# 2    Completed
# 3  In Progress
# 4  In Progress
# 5  Not Started
# 6  Not Started

# %% [markdown]
# Find the name of employee working on 'Project Alfa'

# %%
query = '''
select e.emp_name
from employees e
JOIN employee_projects ep ON  e.emp_id = ep.emp_id
JOIN projects p ON ep.project_id = p.project_id
Where p.project_name = 'Project Alpha'
'''
df = pd.read_sql_query(query, conn)
df
# Out:
#   emp_name
# 0      Ali
# 1     Mohd
# 2     John
# 3    David
# 4   Sophia

# %% [markdown]
# Find all department and the number of employee in each

# %%
query = '''
select d.dept_name, count(e.emp_id) as num_of_employee
from department d
LEFT JOIN employees e ON d.dept_id =e.dept_id
GROUP  BY d.dept_name
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#                 dept_name  num_of_employee
# 0        Customer Support                1
# 1                 Finance                3
# 2                      HR                1
# 3                      IT                2
# 4               Marketing                2
# 5              Operations                1
# 6       Quality Assurance                1
# 7  Research & Development                2
# 8                   Sales                1

# %% [markdown]
# Find the name of employess who are not assigned to any deparment

# %%
query = '''
select emp_name
from employees
where dept_id IS NULL
'''
df = pd.read_sql_query(query, conn)
df
# Out:
#   emp_name
# 0      Raj

# %% [markdown]
# Find Employees  who are working on more than one project.

# %%
query='''
select e.emp_name, Count(ep.project_id) as project_count
from employees e
JOIN employee_projects ep ON e.emp_id = ep.emp_id
Group by e.emp_id, e.emp_name
Having count(ep.project_id)<=1
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#   emp_name  project_count
# 0     Emma              1

# %% [markdown]
# Find employees who are not woking on any project.

# %%
query = '''
select e.emp_name
from employees e
Left JOIN employee_projects ep ON e.emp_id = ep.emp_id
where ep.project_id IS NULL
'''

df = pd.read_sql_query(query, conn)
df
# Out:
# Empty DataFrame
# Columns: [emp_name]
# Index: []

# %% [markdown]
# Find the employee(s) working in the same department as 'ALI'

# %%
query='''
select emp_name
from employees
where dept_id =(
  select dept_id
  from employees
  where emp_name = 'Ali'
)
and emp_name !='Ali'
'''

df = pd.read_sql_query(query, conn)
df
# Out:
# Empty DataFrame
# Columns: [emp_name]
# Index: []

# %% [markdown]
# INNER JOIN :
#
# Only matching rows from both tables
#
# i want record that exist in both tables
#
#
# LEFT JOIN:

# %% [markdown]
# Nested Query (Subqueries) : A nested query is a SQL query inside another query.

# %% [markdown]
# Find employees who are working on same projects as Rahul

# %%
query='''
select Distinct e.emp_name
from employees e
JOIN employee_projects ep ON e.emp_id = ep.emp_id
where ep.project_id IN (
  select ep.project_id
  from employee_projects ep
  JOIN employees e ON ep.emp_id = e.emp_id
  Where e.emp_name='Rahul'
)
'''
df = pd.read_sql_query(query, conn)
df
# Out:
#   emp_name
# 0    Rahul
# 1      Raj
# 2    Priya
# 3   Robert
# 4   Daniel
# 5      Ali
# 6    Ahmed
# 7   Sophia

# %% [markdown]
# List employee whose department has the higest number of employees

# %% [markdown]
# Count employees per department
# Find the department’s with max count
# LIST ALL employees FROM THAT departments

# %%
query='''
select  d.dept_name
from employees e
JOIN department d ON e.dept_id = d.dept_id
where e.dept_id =(
  select dept_id
  from (
    select dept_id,count(*) as emp_count
    from employees
    where dept_id IS NOT NULL
    group by dept_id
    order by emp_count desc
    LIMIT 1
  )

)
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#                 dept_name
# 0  Research & Development
# 1  Research & Development

# %% [markdown]
# Display the name of departments that have no employees

# %%
query = '''
select d.dept_name
from department d
LEFT JOIN employees e ON d.dept_id = e.dept_id
where e.emp_id IS NULL
'''

df = pd.read_sql_query(query, conn)
df
# Out:
# Empty DataFrame
# Columns: [dept_name]
# Index: []

# %% [markdown]
# List of projects that have the most number of employees working on them

# %%
query = '''
select p.project_name,count(ep.emp_id) as eployee_count
from projects p
JOIN employee_projects ep ON p.project_id = ep.project_id
group by p.project_id,p.project_name
Having Count(ep.emp_id) = (
  select MAX(emp_count)
  from (
    select project_id ,count(emp_id) as emp_count
    from employee_projects
    Group by project_id
  )
)
'''
df = pd.read_sql_query(query, conn)
df
# Out:
#     project_name  eployee_count
# 0  Project Alpha              5
# 1   Project Beta              5

# %%
query = '''
select *
from employees e
Left Join department d ON e.dept_id = d.dept_id
LEFT join employee_projects ep ON e.emp_id = ep.emp_id
LEFT Join projects p ON ep.project_id = p.project_id
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#     emp_id emp_name  dept_id  salary gender   join_date  dept_id  \
# 0        1      Ali    101.0    5000      M  2021-05-01    101.0
# 1        1      Ali    101.0    5000      M  2021-05-01    101.0
# 2        2     Mohd    102.0    6000      M  2020-03-15    102.0
# 3        2     Mohd    102.0    6000      M  2020-03-15    102.0
# 4        3    Rahul    103.0    5500      M  2022-01-10    103.0
# 5        3    Rahul    103.0    5500      M  2022-01-10    103.0
# 6        4      Raj      NaN    4500      M  2021-11-22      NaN
# 7        4      Raj      NaN    4500      M  2021-11-22      NaN
# 8        5    Ahmed    105.0    6500      M  2020-07-30    105.0
# 9        5    Ahmed    105.0    6500      M  2020-07-30    105.0
# 10       6    Sneha    104.0    5200      F  2022-02-18    104.0
# 11       6    Sneha    104.0    5200      F  2022-02-18    104.0
# 12       7     John    106.0    7000      M  2019-09-05    106.0
# 13       7     John    106.0    7000      M  2019-09-05    106.0
# 14       8    Priya    108.0    5800      F  2021-08-12    108.0
# 15       8    Priya    108.0    5800      F  2021-08-12    108.0
# 16       9    David    102.0    6200      M  2020-11-30    102.0
# 17       9    David    102.0    6200      M  2020-11-30    102.0
# 18      10   Anjali    109.0    4800      F  2022-03-25    109.0
# 19      10   Anjali    109.0    4800      F  2022-03-25    109.0
# 20      11  Michael    110.0    5300      M  2021-07-14    110.0
# 21      11  Michael    110.0    5300      M  2021-07-14    110.0
# 22      12   Sophia    107.0    5900      F  2020-05-20    107.0
# 23      12   Sophia    107.0    5900      F  2020-05-20    107.0
# 24      13   Robert    103.0    6700      M  2019-12-05    103.0
# 25      13   Robert    103.0    6700      M  2019-12-05    103.0
# 26      14     Emma    106.0    5400      F  2022-01-15    106.0
# 27      15   Daniel    108.0    7100      M  2020-09-10    108.0
# 28      15   Daniel    108.0    7100      M  2020-09-10    108.0
#
#                  dept_name  emp_id  project_id          project_role  \
# 0                       HR       1         201               Manager
# 1                       HR       1         205         HR Consultant
# 2                       IT       2         201             Developer
# 3                       IT       2         204      Senior Developer
# 4                  Finance       3         202               Analyst
# 5                  Finance       3         205     Financial Analyst
# 6                     None       4         202             Developer
# 7                     None       4         206             Developer
# 8                  Finance       5         203               Manager
# 9                  Finance       5         205           Coordinator
# 10                   Sales       6         203              Designer
# 11                   Sales       6         206              Designer
# 12               Marketing       7         201             Developer
# 13               Marketing       7         204       Project Manager
# 14  Research & Development       8         202           UI Designer
# 15  Research & Development       8         206         UI Specialist
# 16                      IT       9         201           QA Engineer
# 17                      IT       9         204             Architect
# 18        Customer Support      10         203                Tester
# 19        Customer Support      10         207          Support Lead
# 20       Quality Assurance      11         203               QA Lead
# 21       Quality Assurance      11         207            QA Manager
# 22              Operations      12         201      Business Analyst
# 23              Operations      12         205    Operations Manager
# 24                 Finance      13         202    Finance Consultant
# 25                 Finance      13         207          Finance Lead
# 26               Marketing      14         204  Marketing Specialist
# 27  Research & Development      15         202             Tech Lead
# 28  Research & Development      15         207    Technical Director
#
#     hours_worked assignment_date  project_id     project_name  project_budget  \
# 0            120      2023-01-10         201    Project Alpha          100000
# 1             60      2023-05-10         205  Project Epsilon           90000
# 2            180      2023-01-10         201    Project Alpha          100000
# 3            200      2023-04-01         204    Project Delta          120000
# 4            150      2023-02-25         202     Project Beta          150000
# 5            120      2023-05-10         205  Project Epsilon           90000
# 6            200      2023-02-25         202     Project Beta          150000
# 7              0      2023-05-30         206     Project Zeta           75000
# 8             90      2023-02-05         203    Project Gamma           80000
# 9            100      2023-05-15         205  Project Epsilon           90000
# 10           160      2023-02-05         203    Project Gamma           80000
# 11             0      2023-05-30         206     Project Zeta           75000
# 12           140      2023-01-15         201    Project Alpha          100000
# 13           150      2023-04-01         204    Project Delta          120000
# 14           110      2023-03-01         202     Project Beta          150000
# 15             0      2023-06-01         206     Project Zeta           75000
# 16            90      2023-01-20         201    Project Alpha          100000
# 17           180      2023-04-05         204    Project Delta          120000
# 18            85      2023-02-15         203    Project Gamma           80000
# 19             0      2023-06-15         207    Project Omega          200000
# 20            95      2023-02-10         203    Project Gamma           80000
# 21             0      2023-06-15         207    Project Omega          200000
# 22            75      2023-01-12         201    Project Alpha          100000
# 23           130      2023-05-12         205  Project Epsilon           90000
# 24            60      2023-03-05         202     Project Beta          150000
# 25             0      2023-06-20         207    Project Omega          200000
# 26            70      2023-04-10         204    Project Delta          120000
# 27           180      2023-02-28         202     Project Beta          150000
# 28             0      2023-06-18         207    Project Omega          200000
#
#     start_date    end_date       status
# 0   2023-01-15  2023-06-30    Completed
# 1   2023-05-15  2023-10-10  In Progress
# 2   2023-01-15  2023-06-30    Completed
# 3   2023-04-05  2023-09-30  In Progress
# 4   2023-03-01  2023-08-15  In Progress
# 5   2023-05-15  2023-10-10  In Progress
# 6   2023-03-01  2023-08-15  In Progress
# 7   2023-06-01  2023-11-15  Not Started
# 8   2023-02-10  2023-05-20    Completed
# 9   2023-05-15  2023-10-10  In Progress
# 10  2023-02-10  2023-05-20    Completed
# 11  2023-06-01  2023-11-15  Not Started
# 12  2023-01-15  2023-06-30    Completed
# 13  2023-04-05  2023-09-30  In Progress
# 14  2023-03-01  2023-08-15  In Progress
# 15  2023-06-01  2023-11-15  Not Started
# 16  2023-01-15  2023-06-30    Completed
# 17  2023-04-05  2023-09-30  In Progress
# 18  2023-02-10  2023-05-20    Completed
# 19  2023-07-10  2024-01-20  Not Started
# 20  2023-02-10  2023-05-20    Completed
# 21  2023-07-10  2024-01-20  Not Started
# 22  2023-01-15  2023-06-30    Completed
# 23  2023-05-15  2023-10-10  In Progress
# 24  2023-03-01  2023-08-15  In Progress
# 25  2023-07-10  2024-01-20  Not Started
# 26  2023-04-05  2023-09-30  In Progress
# 27  2023-03-01  2023-08-15  In Progress
# 28  2023-07-10  2024-01-20  Not Started

# %%
df=pd.read_sql_query( '''
select *
from employees e
Left Join department d ON e.dept_id = d.dept_id
LEFT join employee_projects ep ON e.emp_id = ep.emp_id
LEFT Join projects p ON ep.project_id = p.project_id
''', conn)

# %%
df
# Out:
#     emp_id emp_name  dept_id  salary gender   join_date  dept_id  \
# 0        1      Ali    101.0    5000      M  2021-05-01    101.0
# 1        1      Ali    101.0    5000      M  2021-05-01    101.0
# 2        2     Mohd    102.0    6000      M  2020-03-15    102.0
# 3        2     Mohd    102.0    6000      M  2020-03-15    102.0
# 4        3    Rahul    103.0    5500      M  2022-01-10    103.0
# 5        3    Rahul    103.0    5500      M  2022-01-10    103.0
# 6        4      Raj      NaN    4500      M  2021-11-22      NaN
# 7        4      Raj      NaN    4500      M  2021-11-22      NaN
# 8        5    Ahmed    105.0    6500      M  2020-07-30    105.0
# 9        5    Ahmed    105.0    6500      M  2020-07-30    105.0
# 10       6    Sneha    104.0    5200      F  2022-02-18    104.0
# 11       6    Sneha    104.0    5200      F  2022-02-18    104.0
# 12       7     John    106.0    7000      M  2019-09-05    106.0
# 13       7     John    106.0    7000      M  2019-09-05    106.0
# 14       8    Priya    108.0    5800      F  2021-08-12    108.0
# 15       8    Priya    108.0    5800      F  2021-08-12    108.0
# 16       9    David    102.0    6200      M  2020-11-30    102.0
# 17       9    David    102.0    6200      M  2020-11-30    102.0
# 18      10   Anjali    109.0    4800      F  2022-03-25    109.0
# 19      10   Anjali    109.0    4800      F  2022-03-25    109.0
# 20      11  Michael    110.0    5300      M  2021-07-14    110.0
# 21      11  Michael    110.0    5300      M  2021-07-14    110.0
# 22      12   Sophia    107.0    5900      F  2020-05-20    107.0
# 23      12   Sophia    107.0    5900      F  2020-05-20    107.0
# 24      13   Robert    103.0    6700      M  2019-12-05    103.0
# 25      13   Robert    103.0    6700      M  2019-12-05    103.0
# 26      14     Emma    106.0    5400      F  2022-01-15    106.0
# 27      15   Daniel    108.0    7100      M  2020-09-10    108.0
# 28      15   Daniel    108.0    7100      M  2020-09-10    108.0
#
#                  dept_name  emp_id  project_id          project_role  \
# 0                       HR       1         201               Manager
# 1                       HR       1         205         HR Consultant
# 2                       IT       2         201             Developer
# 3                       IT       2         204      Senior Developer
# 4                  Finance       3         202               Analyst
# 5                  Finance       3         205     Financial Analyst
# 6                     None       4         202             Developer
# 7                     None       4         206             Developer
# 8                  Finance       5         203               Manager
# 9                  Finance       5         205           Coordinator
# 10                   Sales       6         203              Designer
# 11                   Sales       6         206              Designer
# 12               Marketing       7         201             Developer
# 13               Marketing       7         204       Project Manager
# 14  Research & Development       8         202           UI Designer
# 15  Research & Development       8         206         UI Specialist
# 16                      IT       9         201           QA Engineer
# 17                      IT       9         204             Architect
# 18        Customer Support      10         203                Tester
# 19        Customer Support      10         207          Support Lead
# 20       Quality Assurance      11         203               QA Lead
# 21       Quality Assurance      11         207            QA Manager
# 22              Operations      12         201      Business Analyst
# 23              Operations      12         205    Operations Manager
# 24                 Finance      13         202    Finance Consultant
# 25                 Finance      13         207          Finance Lead
# 26               Marketing      14         204  Marketing Specialist
# 27  Research & Development      15         202             Tech Lead
# 28  Research & Development      15         207    Technical Director
#
#     hours_worked assignment_date  project_id     project_name  project_budget  \
# 0            120      2023-01-10         201    Project Alpha          100000
# 1             60      2023-05-10         205  Project Epsilon           90000
# 2            180      2023-01-10         201    Project Alpha          100000
# 3            200      2023-04-01         204    Project Delta          120000
# 4            150      2023-02-25         202     Project Beta          150000
# 5            120      2023-05-10         205  Project Epsilon           90000
# 6            200      2023-02-25         202     Project Beta          150000
# 7              0      2023-05-30         206     Project Zeta           75000
# 8             90      2023-02-05         203    Project Gamma           80000
# 9            100      2023-05-15         205  Project Epsilon           90000
# 10           160      2023-02-05         203    Project Gamma           80000
# 11             0      2023-05-30         206     Project Zeta           75000
# 12           140      2023-01-15         201    Project Alpha          100000
# 13           150      2023-04-01         204    Project Delta          120000
# 14           110      2023-03-01         202     Project Beta          150000
# 15             0      2023-06-01         206     Project Zeta           75000
# 16            90      2023-01-20         201    Project Alpha          100000
# 17           180      2023-04-05         204    Project Delta          120000
# 18            85      2023-02-15         203    Project Gamma           80000
# 19             0      2023-06-15         207    Project Omega          200000
# 20            95      2023-02-10         203    Project Gamma           80000
# 21             0      2023-06-15         207    Project Omega          200000
# 22            75      2023-01-12         201    Project Alpha          100000
# 23           130      2023-05-12         205  Project Epsilon           90000
# 24            60      2023-03-05         202     Project Beta          150000
# 25             0      2023-06-20         207    Project Omega          200000
# 26            70      2023-04-10         204    Project Delta          120000
# 27           180      2023-02-28         202     Project Beta          150000
# 28             0      2023-06-18         207    Project Omega          200000
#
#     start_date    end_date       status
# 0   2023-01-15  2023-06-30    Completed
# 1   2023-05-15  2023-10-10  In Progress
# 2   2023-01-15  2023-06-30    Completed
# 3   2023-04-05  2023-09-30  In Progress
# 4   2023-03-01  2023-08-15  In Progress
# 5   2023-05-15  2023-10-10  In Progress
# 6   2023-03-01  2023-08-15  In Progress
# 7   2023-06-01  2023-11-15  Not Started
# 8   2023-02-10  2023-05-20    Completed
# 9   2023-05-15  2023-10-10  In Progress
# 10  2023-02-10  2023-05-20    Completed
# 11  2023-06-01  2023-11-15  Not Started
# 12  2023-01-15  2023-06-30    Completed
# 13  2023-04-05  2023-09-30  In Progress
# 14  2023-03-01  2023-08-15  In Progress
# 15  2023-06-01  2023-11-15  Not Started
# 16  2023-01-15  2023-06-30    Completed
# 17  2023-04-05  2023-09-30  In Progress
# 18  2023-02-10  2023-05-20    Completed
# 19  2023-07-10  2024-01-20  Not Started
# 20  2023-02-10  2023-05-20    Completed
# 21  2023-07-10  2024-01-20  Not Started
# 22  2023-01-15  2023-06-30    Completed
# 23  2023-05-15  2023-10-10  In Progress
# 24  2023-03-01  2023-08-15  In Progress
# 25  2023-07-10  2024-01-20  Not Started
# 26  2023-04-05  2023-09-30  In Progress
# 27  2023-03-01  2023-08-15  In Progress
# 28  2023-07-10  2024-01-20  Not Started

# %% [markdown]
# Sort by salary (desc)

# %%
df[['emp_name','salary']].drop_duplicates().sort_values(by='salary',ascending=False)
# Out:
#    emp_name  salary
# 27   Daniel    7100
# 12     John    7000
# 24   Robert    6700
# 8     Ahmed    6500
# 16    David    6200
# 2      Mohd    6000
# 22   Sophia    5900
# 14    Priya    5800
# 4     Rahul    5500
# 26     Emma    5400
# 20  Michael    5300
# 10    Sneha    5200
# 0       Ali    5000
# 18   Anjali    4800
# 6       Raj    4500

# %% [markdown]
# Employess from 'it' department with salary >5000

# %%
df[(df['dept_name']=='IT')& (df['salary']>5000)]
# Out:
#     emp_id emp_name  dept_id  salary gender   join_date  dept_id dept_name  \
# 2        2     Mohd    102.0    6000      M  2020-03-15    102.0        IT
# 3        2     Mohd    102.0    6000      M  2020-03-15    102.0        IT
# 16       9    David    102.0    6200      M  2020-11-30    102.0        IT
# 17       9    David    102.0    6200      M  2020-11-30    102.0        IT
#
#     emp_id  project_id      project_role  hours_worked assignment_date  \
# 2        2         201         Developer           180      2023-01-10
# 3        2         204  Senior Developer           200      2023-04-01
# 16       9         201       QA Engineer            90      2023-01-20
# 17       9         204         Architect           180      2023-04-05
#
#     project_id   project_name  project_budget  start_date    end_date  \
# 2          201  Project Alpha          100000  2023-01-15  2023-06-30
# 3          204  Project Delta          120000  2023-04-05  2023-09-30
# 16         201  Project Alpha          100000  2023-01-15  2023-06-30
# 17         204  Project Delta          120000  2023-04-05  2023-09-30
#
#          status
# 2     Completed
# 3   In Progress
# 16    Completed
# 17  In Progress

# %% [markdown]
# Show all project with their budget and start date

# %%
query = '''
select project_name,
project_budget,
start_date
from projects
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#       project_name  project_budget  start_date
# 0    Project Alpha          100000  2023-01-15
# 1     Project Beta          150000  2023-03-01
# 2    Project Gamma           80000  2023-02-10
# 3    Project Delta          120000  2023-04-05
# 4  Project Epsilon           90000  2023-05-15
# 5     Project Zeta           75000  2023-06-01
# 6    Project Omega          200000  2023-07-10

# %% [markdown]
# Show employees with the same joining date

# %%
pd.read_sql_query('''
select e1.emp_name,
e2.emp_name,
e1.join_date
from employees e1
Join employees e2
ON e1.join_date =e2.join_date
And e1.emp_id < e2.emp_id
ORDER BY e1.join_date
''', conn)
# Out:
# Empty DataFrame
# Columns: [emp_name, emp_name, join_date]
# Index: []

# %%
pd.read_sql_query('''
select
e.emp_id,
e.emp_name,
CASE
when ep.project_id IS NOT NULL THEN 'YES'
ELSE 'NO"
END as is_assigned_to_project
From employees e
Left Join employee_projects ep ON e.emp_id = ep.emp_id
group by e.emp_id
''', conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: unrecognized token: "'NO"
# END as is_assigned_to_project
# From employees e
# Left Join employee_projects ep ON e.emp_id = ep.emp_id
# group by e.emp_id
# "
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-20-7aa78c545475> in <cell line: 0>()
# ----> 1 pd.read_sql_query('''
#       2 select
#       3 e.emp_id,
#       4 e.emp_name,
#       5 CASE
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql '
# select
# e.emp_id,
# e.emp_name,
# CASE
# when ep.project_id IS NOT NULL THEN 'YES'
# ELSE 'NO"
# END as is_assigned_to_project
# From employees e
# Left Join employee_projects ep ON e.emp_id = ep.emp_id
# group by e.emp_id
# ': unrecognized token: "'NO"
# END as is_assigned_to_project
# From employees e
# Left Join employee_projects ep ON e.emp_id = ep.emp_id
# group by e.emp_id
# "

# %% [markdown]
# self Join : a self join is the join where a table joined with itself

# %% [markdown]
# List all employee and there project name?

# %%
query = '''
select e.emp_name,p.project_name
from employees e
LEFT JOIN employee_projects ep ON e.emp_id = ep.emp_id
LEFT JOIN projects p ON ep.project_id = p.project_id
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# employee without project

# %%
query = '''
select e.emp_name
from employees e
LEFT JOIN employee_projects ep ON e.emp_id = ep.emp_id
where ep.project_id IS NULL
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Project with multiple employee

# %%
query = '''
select p.project_name, count(emp_id) as num_employes
from projects p
JOIN employee_projects ep ON p.project_id = ep.project_id
GROUP BY p.project_id
HAVING count(ep.emp_id) > 1
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# FULL OUTER JOIN (with UNION)

# %% [markdown]
# List all employees and projects

# %%
query = '''
select e.emp_name,p.project_name
from employees e
LEFT JOIN employee_projects ep ON e.emp_id = ep.emp_id
LEFT JOIN projects p ON ep.project_id = p.project_id

UNION

select e.emp_name,p.project_name
from projects p
LEFT JOIN employee_projects ep ON p.project_id = ep.project_id
LEFT JOIN employees e ON ep.emp_id = e.emp_id
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# show department with average salary above 5000

# %%
query = '''
select d.dept_name,AVG(e.salary) as avy_salary
from department d
join employees e ON d.dept_id=e.dept_id
group by d.dept_id
HAVING avg(e.salary) > 5000
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# which department has the  most employees working on project?

# %%
query = '''
select d.dept_name,count(distinct e.emp_id) as employee_count
from department d
JOIN employees e ON d.dept_id=e.dept_id
JOIN employee_projects ep ON e.emp_id = ep.emp_id
group by d.dept_id
order by employee_count desc
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Show the latest joiner in each department

# %%
query = '''
select e1.dept_id,d.dept_name,e1.emp_name,e1.join_date
from employees e1
JOIN department  d ON e1.dept_id =d.dept_id
where join_date = (
  select MAX(e2.join_date)
  from employees e2
  where e1.dept_id = e2.dept_id
)
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# SELECT & FINTERING
#
# JOIN
#
# AGGREGATE FUNTION
#
# GROUP BY & HAVING
#
# CASE STATEMENT
#
# UNION & INTERSECT
#
# EXITS
#
# Any and all

# %% [markdown]
# COUNT THE employee IN EACH DEPARTMENT

# %%
query = '''
select d.dept_name, COUNT(e.emp_id) as num_employes
from department d
LEFT JOIN employees e ON d.dept_id = e.dept_id
Group by d.dept_id;

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Total hours worked by each employees

# %%
query = '''
select e.emp_name,SUM(ep.hours_worked) as total_hours
from employees e
JOIN employee_projects ep ON e.emp_id = ep.emp_id
group by e.emp_id
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Average salary per department

# %%
query = '''
select d.dept_name, AVG(e.salary) as avg_salary
from employees e
JOIN department d ON e.dept_id = d.dept_id
GROUP BY d.dept_id
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# MAX & MIN salary in each department

# %%
query = '''
select d.dept_name,
MAX(e.salary) as max_salary,
MIN(e.salary) as min_salary
from department d
JOIN employees e ON d.dept_id = e.dept_id
group by d.dept_id;
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Total Hours worked per Department

# %%
query = '''
select d.dept_name,SUM(ep.hours_worked) as dept_hours
from department d
JOIN employees e ON d.dept_id = e.dept_id
JOIN employee_projects ep ON e.emp_id = ep.emp_id
Group by d.dept_id
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Employees  who worked more than 100 hours tatal

# %%
query = '''
select e.emp_name ,SUM(ep.hours_worked) as total_hours
from employees e
JOIN employee_projects ep ON e.emp_id = ep.emp_id
Group by e.emp_id
Having total_hours > 100

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Total number of project per employees

# %%
query = '''
select e.emp_name, COUNT(ep.project_id) as project_count
from employees e
LEFT JOIN employee_projects ep ON e.emp_id = ep.emp_id
GROUP BY e.emp_id

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# FIND THE AVERAGE HOURS WORKED BY employee IN EACH department

# %%
query = '''
SELECT d.dept_name, AVG(ep.hours_worked) AS avg_hours
FROM department d
JOIN employees e ON d.dept_id = e.dept_id
JOIN employee_projects ep ON e.emp_id = ep.emp_id
GROUP BY d.dept_id;
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# TOTAL NUMBER OF departments THAT HAVE MORE THAN 1 employees

# %%
query = '''
SELECT d.dept_name, COUNT(e.emp_id) AS employee_count
FROM employees e
JOIN department d ON e.dept_id = d.dept_id
GROUP BY d.dept_id
HAVING COUNT(e.emp_id) > 1;

'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# FOR EACH PROJECT ,FIND HOW MANY departments are involved

# %%
query = '''
SELECT p.project_name, COUNT(DISTINCT e.dept_id) AS dept_count
FROM projects p
JOIN employee_projects ep ON p.project_id = ep.project_id
JOIN employees e ON ep.emp_id = e.emp_id
GROUP BY p.project_id;
'''
df = pd.read_sql_query(query, conn)
df

# %%
query = '''
SELECT COUNT(*) AS employees_without_projects
FROM employees e
LEFT JOIN employee_projects ep ON e.emp_id = ep.emp_id
WHERE ep.project_id IS NULL;
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# GROUP BY & HAVING

# %% [markdown]
# List department that have more than 3 employee

# %%
query = '''
select dept_id ,count(*) as employe_count
from employees
GROUP BY dept_id
HAVING COUNT(*) >1;
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Find project where the average hours worked is more than 40

# %% [markdown]
# Aggregate
# GROUP HAVING
# HAVING

# %%
query = '''
select project_id , avg(hours_worked) as avg_hours
from employee_projects
GROUP BY project_id
HAVING AVG(hours_worked) > 40
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# SHOW department with an avg salary btw 5k to 7k

# %%
query = '''
select d.dept_name, AVG(e.salary) as avg_salary
from department d
JOIN employees e ON d.dept_id = e.dept_id
GROUP BY d.dept_id
HAVING AVG(e.salary) BETWEEN 6000 and 7000;
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# List project that have more than 2 employee assigned

# %%
query = '''
select p.project_name, COUNT(ep.emp_id) as employé_count
from projects p
JOIN employee_projects ep ON p.project_id = ep.project_id
GROUP BY p.project_id
HAVING count(ep.emp_id) > 2;
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Find project with avg hours worked less than 35

# %%
query = '''
select p.project_name, AVG(ep.hours_worked) as avg_hours
from projects p
JOIN employee_projects ep ON p.project_id = ep.project_id
GROUP BY p.project_id
HAVING AVG(ep.hours_worked) < 200;
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# List department with the higest number of employee (top 1 only )

# %% [markdown]
# Find departments where the avg join year is before 2020

# %%
query = '''
SELECT d.dept_name, AVG(STRFTIME('%Y', e.join_date)) AS avg_join_year
FROM employees e
JOIN department d ON e.dept_id = d.dept_id
GROUP BY d.dept_id
HAVING AVG(STRFTIME('%Y', e.join_date)) < 2021;
'''

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
SELECT
    p.project_name,
    COUNT(DISTINCT e.dept_id) AS dept_count,
    GROUP_CONCAT(DISTINCT d.dept_name) AS departments_involved
FROM projects p
JOIN employee_projects ep ON p.project_id = ep.project_id
JOIN employees e ON ep.emp_id = e.emp_id
JOIN department d ON e.dept_id = d.dept_id
GROUP BY p.project_id, p.project_name;

'''
df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select p.project_name , d.dept_name,Count(*) as dept_employee_count
from employee_projects ep
JOIN employees e ON ep.emp_id = e.emp_id
JOIN department d ON e.dept_id = d.dept_id
JOIN projects p ON ep.project_id = p.project_id
GROUP BY ep.project_id , e.dept_id
HAVING COUNT(*) =(
  select MAX(dept_count)
  FROM (
    select COUNT(*) as dept_count
    From employee_projects ep2
    JOIN employees e2 ON ep2.emp_id =e2.emp_id
    where ep2.project_id = ep.project_id
    Group by e2.dept_id
  )
);

'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# CASE STATEMENT

# %% [markdown]
# Show employees and categorize their salary level as "LOW" "MEDIUM' or HIGH

# %%
query = '''
select emp_name,
salary,
CASE
  When salary < 4000 THEN 'LOW'
  WHEN salary BETWEEN 4000 AND 7000 THEN 'MEDIUM'
  ELSE 'HIGH'
end as salary_level
from employees
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# List all employees and mark 'YES' or 'NO' if they are asigned to a project

# %%
query = '''
select e.emp_name,
CASE
    When ep.emp_id IS NOT NULL THEN 'YES'
    ELSE 'NO'
end as assigned_to_project
FROM employees e
LEFT JOIN employee_projects ep ON e.emp_id = ep.emp_id
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Tag employee as 'experienced' if they join before 2020, else 'New'

# %%
query = '''
select emp_name,
join_date,
CASE when join_date < '2020-01-01' THEN 'Experienced'
Else 'New'
end as exp_level
from employees
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Show employees with a custom message based on their department

# %%
query = '''
select
emp_name,
d.dept_name,
CASE d.dept_name
when 'HR' THEN 'Handles hiring and polices'
When 'IT' THEN 'Responsible for Tech'
When 'Finance' Then 'Manage company finance'
else 'Other departments'
end as department_role
from employees e
JOIN department d ON e.dept_id = d.dept_id

'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# show employees load : high/medium/low based on avg hours per project

# %%
query = '''
select e.emp_name,
count(ep.project_id) as project_count,
sum(ep.hours_worked) as total_hours,
case
when count(ep.project_id) = 0 Then 'No project'
when sum(ep.hours_worked) / count(ep.project_id) >= 40 Then 'High Load'
when sum(ep.hours_worked) / count(ep.project_id) BETWEEN 30 AND 40 THEN 'MEDIUM LOAD'
else 'Low Load'
end as worked_level
From employees e
Left join employee_projects ep ON e.emp_id = ep.emp_id
GROUP BY e.emp_id

'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Exist

# %% [markdown]
# Find the employees who are assigned to at least one project

# %%
query = '''
select emp_name
from employees e
where exists (
  select 1
  from employee_projects ep
  where ep.emp_id =e.emp_id

)

'''
df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select distinct e.emp_name
from employees e
JOIN employee_projects ep ON e.emp_id =ep.emp_id

'''
df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select   emp_name
from employees e
where emp_id IN (
  select emp_id from employee_projects
)


'''
df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select   emp_name
from employees e
LEFT join employee_projects ep on e.emp_id =ep.emp_id
where ep.emp_id is not null


'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Find employees who are not assigned any project

# %%
query = '''
select emp_name
from employees e
where not exists (
  select 1
  from employee_projects ep
  where ep.emp_id =e.emp_id

)

'''
df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select emp_name
from employees
where emp_id NOT IN (
  select emp_id from employee_projects
 )
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# show project that have employees from the 'IT' departments

# %%
query = '''
select Distinct p.project_name,e.emp_name
from projects p
join employee_projects ep on p.project_id = ep.project_id
JOIN employees e ON ep.emp_id = e.emp_id
JOIN department d on e.dept_id = d.dept_id
where d.dept_name = 'IT'

'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# exist

# %%
query = '''
select Distinct p.project_name,e.emp_name
from projects p
join employee_projects ep on p.project_id = ep.project_id
JOIN employees e ON ep.emp_id = e.emp_id
where exists (
  select 1
  from department d
  where d.dept_id = e.dept_id
  and d.dept_name ='IT'

)
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# List department that have no employees at all

# %%
query = '''
select d.dept_name
from department d
where NOT exists (
  select 0 from employees e
  where e.dept_id = d.dept_id

)

'''

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select d.dept_name
from department d
LEFT JOIN employees e ON d.dept_id = e.dept_id
where e.emp_id IS NULL

'''

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select d.dept_name
from department d
where dept_id NOT IN (
  select distinct dept_id from employees where dept_id IS NOT NULL
)

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# List department that have employees

# %%
query = '''
select distinct  d.dept_name
from department d
JOIN employees e ON d.dept_id =e.dept_id

'''

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select d.dept_name
from department d
where dept_id IN (
  select distinct dept_id
  from employees
  where dept_id IS NOT NULL
)

'''

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select d.dept_name
from department d
join employees e ON d.dept_id = e.dept_id
group by d.dept_id
Having count(e.emp_id) > 0

'''

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select d.dept_name
from department d
where exists (
  select 1
  from employees e
  where e.dept_id = d.dept_id
)

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Show emp whose departments have more than 2 employees

# %%
query = '''
select emp_name
from employees
where dept_id IN (
  select dept_id
  from employees
  group by dept_id
  having count(*) >1
)
'''

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select e.emp_name
from employees e
JOIN (
  select dept_id
  from employees
  group by dept_id
  Having count(*)>1
) dept_grouped ON e.dept_id = dept_grouped.dept_id
'''

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select emp_name
from employees e
where exists (
  select 1
  from employees e2
  where e2.dept_id = e.dept_id
  group by e2.dept_id
  having count(*)> 1
)
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Find employees who work on the same project as "ali"

# %%
query = '''
select emp_name
from employees
where emp_id IN (
  select emp_id
  from employee_projects
  where project_id IN (
    select project_id
    from employee_projects ep
    JOIN employees e ON ep.emp_id =e.emp_id
    where e.emp_name ='Ali'
  )
)
and emp_name <> 'Ali'

'''
df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select e2.emp_name
from employees e1
JOIN employee_projects ep1 ON e1.emp_id = ep1.emp_id
JOIN employee_projects ep2 ON ep1.project_id = ep2.project_id
JOIN employees e2 ON ep2.emp_id = e2.emp_id
where e1.emp_name ='Ali' and e2.emp_name <> 'Ali'


'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Union

# %% [markdown]
# List all unique department IDs and project id

# %%
query = '''
select dept_id from employees
UNION
select project_id from employee_projects

'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Get names of all employee and all department ( as a single list)

# %%
query = '''
select emp_name as name from employees
UNION
select dept_name from department
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Find employees who are either in the 'IT' department or assigned to 'project as
# alpha'

# %%
query = '''
select emp_name from employees e
JOIN department  d ON e.dept_id = d.dept_id
Where d.dept_name ='IT'

UNION

select ep.emp_id from employee_projects ep
JOIN projects p ON ep.project_id = p.project_id
where p.project_name ='Project Alpha'
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Find employees who are in 'sales' or 'Marketing' but not assigned any projects

# %%
query = '''
select e.emp_id from employees e
JOIN department d ON e.dept_id = d.dept_id
where d.dept_name IN ('Sales' , 'Marketing')

Except

select emp_id from employee_projects
'''
df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select e.emp_id,e.emp_name
from employees e
JOIN department d ON e.dept_id = d.dept_id
Where d.dept_name IN ('Sales', 'Marketing')
and e.emp_id NOT IN (
  select emp_id from employee_projects
)
'''
df = pd.read_sql_query(query, conn)
df

# %%
List all employees who are either in HR or working on project Beta

# %%
query = '''
select e.emp_name from employees e
JOIN department d ON e.dept_id =d.dept_id
Where d.dept_name = 'HR'

UNION

select e.emp_name from employees e
JOIN employee_projects ep ON e.emp_id = ep.emp_id
JOIN projects p ON ep.project_id = p.project_id
Where p.project_name = 'Project Beta'
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# List employees who either joined in or after 2020 or are working on project alpha

# %%
query = '''
select emp_name from employees
where join_date >= 2020

UNION

select e.emp_name from employees e
JOIN employee_projects ep ON e.emp_id = ep.emp_id
JOIN projects p ON ep.project_id = p.project_id
Where p.project_name = 'Project Alpha'
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# List all unique name of departments  and projects that start with 'F'

# %%
query = '''
select dept_name as Name from department
where dept_name Like 'S%'

UNION

select project_name from projects
where project_name Like 'A%'
'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# List name of employee who are assigned to both 'project Alpha' and 'project Beta'

# %%
query = '''
select e.emp_name
from employees e
where Exists (
  select 1
  from employee_projects ep
  JOIN projects p ON ep.project_id =p.project_id
  where ep.emp_id = e.emp_id and p.project_name = 'Project Omega'
)

and Exists (
  select 1
  from employee_projects ep
  JOIN projects p ON ep.project_id =p.project_id
  where ep.emp_id = e.emp_id and p.project_name = 'Project Beta'

)

'''
df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# ANY & All

# %% [markdown]
# Employee whose ID is greater than any employees in the 'IT' department

# %%
query = '''
select emp_name
from employees
where emp_id > (
  select MIN(e.emp_id)
  from employees e
  JOIN department d ON e.dept_id = d.dept_id
  where d.dept_name ='IT'
)
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Find employees whose id is greater than all employee in the HR department

# %%
query = '''
select emp_name
from employees
where emp_id > ALL (
  select emp_id from employees e
  JOIN department d ON e.dept_id = d.dept_id
  Where d.dept_name = 'HR'
)
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Sub query: A subquery ( also inner query or nested query ) is a query inside another query
#
# Filter data
#
# perform comparisons

# %% [markdown]
# Find employee who belong to 'IT' departments

# %%
query = """
Select emp_name
from employees
where dept_id = (
  Select dept_id from department where dept_name = 'IT'
)
"""

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select emp_name
from employees e
JOIN department d ON e.dept_id = d.dept_id
where d.dept_name = 'IT'
'''

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select emp_name
from employees
Natural Join department
where dept_name = 'IT'
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Find employees who earn more than average salary

# %%
query = '''
select emp_name ,salary
from employees
Where salary > (
  select AVG(salary)
  from employees
)
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# List project that 'ALI' is not working on

# %% [markdown]
# IS NULL

# %%
query = '''
select p.project_name
from projects p
LEFT JOIN employee_projects ep ON p.project_id = ep.project_id
LEFT JOIN employees e ON ep.emp_id = e.emp_id AND e.emp_name ='Ali'
where e.emp_id IS NULL
'''

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select p.project_name
from projects p
LEFT JOIN employee_projects ep ON p.project_id = ep.project_id
LEFT JOIN employees e ON ep.emp_id = e.emp_id
where e.emp_name != 'Ali'
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Except

# %%
query = '''
select project_name
from projects
EXCEPT
select p.project_name
from projects p
LEFT JOIN employee_projects ep ON p.project_id = ep.project_id
LEFT JOIN employees e ON ep.emp_id = e.emp_id
where e.emp_name = 'Ali'
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# NOT EXIST

# %%
query = '''
select project_name
from projects p
where NOT EXISTS (
  select 1
  from employee_projects ep
  JOIN employees e ON ep.emp_id = e.emp_id
  Where e.emp_name = 'Ali' AND ep.project_id = p.project_id
)
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# NOT IN

# %%
query = '''
select project_name
from projects
where project_id NOT IN (
  select project_id
  from employee_projects ep
  JOIN employees  e ON ep.emp_id = e.emp_id
  where e.emp_name = 'Ali'
)
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Show employees whose departments  has more than 2 employees

# %%
query = '''
select e.emp_name,d.dept_name
from employees e
JOIN department d ON e.dept_id = d.dept_id
where e.dept_id IN (
  select dept_id
  from employees
  Group by dept_id
  Having count(*) >=  2
  )
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Find employees who belong to the same departments as 'Ali'

# %%
query = '''
select emp_id
  from employee_projects
  Group by emp_id
  order by count(*) desc
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Find all employee who work same project as Mohd

# %%
query = '''
select emp_name
from employees
where emp_id IN (
  select emp_id
  from employee_projects
  where project_id IN (
    select project_id
    from employee_projects
    where emp_id = (
      select emp_id From employees where emp_name ='Mohd'
    )
  )
)
And emp_name != 'Mohd'
'''

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
SELECT  2
    FROM employee_projects ep
    JOIN employees e ON ep.emp_id = e.emp_id
    join projects p on ep.project_id = p.project_id
    WHERE
    e.dept_id = (SELECT dept_id FROM department WHERE dept_name = 'IT')
'''

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
SELECT project_name
FROM projects p
WHERE EXISTS (
    SELECT 1
    FROM employee_projects ep
    JOIN employees e ON ep.emp_id = e.emp_id
    WHERE ep.project_id = p.project_id
    AND e.dept_id = (SELECT dept_id FROM department WHERE dept_name = 'IT')
)

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Introduction to SQL
#
# Database ,table,row,column,concept
#
# select statement
#
# where
#
# order by
#
# limit/offset
#
# Distinct
#
# Aliases
#
# AND/OR/NOT
#
# Between ,IN,NOT IN
#
# LIKE
#
# IS NULL / IS NOT NULL
#
# COUNT(),SUM(),AVG(),MIN(),MAX()
#
# GROUP BY
#
# HAVING
#
# JOINS
#
# INNER JOIN
#
# LEFT JOIN
#
# RIGHT JOIN
#
# FULL OUTER JOIN
#
# NESTED queries (SUB queries )
#
# UNION/UNION ALL
#
# INTERSECT
#
# EXCEPT
#
# CASE WHEN THEN ELSE END
#
# IF /NULL IF
#
# WINDOW FUNTION
#
# AGGREGATE
# COUNT(),SUM(),AVG(),MIN(),MAX()
#
#
# ROW_NUMBER(),RANK(),DENSE()
#
# CTE (COMMON TABLE EXPRESSION)
#
#
# VIEWS
# Indexes
# Data Modeling
# Query opt.

# %% [markdown]
# Window Funtion: A window funtion is a special type of funtion in sql that let you perform calculation across rows

# %% [markdown]
# Show each employee and the total number of employee in their department

# %%
query = '''
select emp_name,dept_id,
count(*) OVER(PARTITION BY dept_id) as total_in_dept
from employees;
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Show each employee and there average salary in their departments

# %%
query = '''
Select emp_name,dept_id,salary,
AVG(salary) OVER (PARTITION BY dept_id ) as avg_dept_salary
From employees;
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Show each employees and their departments max salary

# %%
query = '''
Select emp_name,dept_id,salary,
Max(salary) OVER (PARTITION BY dept_id ) as max_dept_salary
From employees;
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Get difference in salary between  each employee and the average salary in their department

# %%
query = '''
select emp_name,dept_id,salary,
AVG(salary) OVER (PARTITION BY dept_id ) as avg_dept_salary,
salary - AVG(salary) OVER (PARTITION BY dept_id ) as diff_from_avg
from employees;
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# display each project and total hours worked by all employees on that project

# %%
query = '''
select p.project_name,ep.emp_id,ep.hours_worked,
SUM(hours_worked) OVER (PARTITION BY p.project_id) as total_hours_on_projects
from employee_projects ep
JOIN projects p ON ep.project_id = p.project_id
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# For each employee , show total number of project assigned and cumulative hour worked

# %%
query = '''
select emp_id,
COUNT(project_id) OVER (PARTITION BY emp_id ) as total_project,
SUM(hours_worked) OVER (PARTITION BY emp_id ) as total_hours
from employee_projects
'''

df = pd.read_sql_query(query, conn)
df

# %%
query = '''
select
e.emp_name,
p.project_name,
ep.hours_worked,

COUNT(*) OVER (PARTITION BY e.emp_id ) as total_project,
SUM(ep.hours_worked) OVER (PARTITION BY e.emp_id ) as total_hours

From employees e

JOIN employee_projects ep ON e.emp_id = ep.emp_id
JOIN projects p ON ep.project_id = p.project_id
order by e.emp_name

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# show departments where the top salary is greater than 5000

# %%
query = '''
select emp_name,dept_id,salary,max_salary_in_dept
from (
  select emp_name,dept_id, salary ,
  MAX(salary) OVER (PARTITION BY dept_id ) as max_salary_in_dept
  from employees
)
where max_salary_in_dept> 5000;

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Show each employees joining date and the earlist join date in their department

# %%
query = '''
SELECT emp_name, dept_id, salary
FROM (
    SELECT emp_name, dept_id, salary,
           AVG(salary) OVER (PARTITION BY dept_id) AS avg_salary
    FROM employees
) AS sub
WHERE salary > avg_salary;
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# COUNT(),SUM(),AVG(),MIN(),MAX()

# %% [markdown]
# Q1. show each employees ,their department and the total number of employees in the departments

# %% [markdown]
# For each project ,show the total hours worked by employee

# %% [markdown]
# For each department, show employees whose salary is above the average salary of their department

# %% [markdown]
# show wmployeess with higest salary

# %% [markdown]
# show employees with the lowest salary in each department

# %% [markdown]
# Assign a row number to each employees

# %%
query = '''
select emp_id,emp_name,
row_number() OVER (order by emp_id) as row_num
from employees ;

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Row number by department (orderd by name)

# %%
query = '''
select emp_id,emp_name,dept_id,
ROW_NUMBER() OVER (PARTITION BY dept_id order by emp_name) as row_num
from employees;
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# show the second highest salary employees in each departments

# %%
query = '''
select *
from (
  select emp_id,emp_name,dept_id,salary,
  row_number() OVER (Partition by dept_id ORDER by salary desc) as rn
  from employees
) t

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# List employee in order of joining date with row number

# %%
query = '''
select emp_id,emp_name,join_date,
ROW_NUMBER() Over (order by join_date) as row_num
from employees

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Assign row numbers to employee within each project

# %%
query = '''
select ep.emp_id, e.emp_name,ep.project_id,p.project_name,
ROW_NUMBER() OVER (PARTITION BY ep.project_id ORDER BY e.emp_name) as row_num
From employee_projects ep
join employees e ON ep.emp_id =e.emp_id
JOIN projects p ON ep.project_id =p.project_id
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Find the 3 highest paid employee in the entire company

# %%
query = '''
select *
from (
  select emp_id,emp_name,salary,
  ROW_NUMBER() OVER(order by salary desc) as rn
  from employees
) t

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# List employee with the same salary rank within their departments (use rank)

# %%
query = '''
select e.emp_id,e.emp_name,e.dept_id,e.salary,d.dept_name,
Rank() Over (partition by e.dept_id order by salary desc) as salary_rank
from employees e
JOIN department d ON e.dept_id=d.dept_id;

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# show 2,3 employee alphabetically in each departments

# %%
query = '''
select r.emp_id,r.emp_name,r.dept_id,d.dept_name,row_num
from (
  select e.emp_id,e.emp_name,e.dept_id,
  row_number() Over (PARTITION BY e.dept_id order by e.emp_name) as row_num
  from employees e
) as r
JOIN department d ON r.dept_id = d.dept_id

'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# assign row number to employee in each department

# %%
query = '''
select emp_id,emp_name,dept_id,
ROW_NUMBER() OVER (PARTITION BY dept_id ORDER BY emp_name) as dept_row_number
from employees
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# List employee in each departments  by salary with both RANK() and DENSE RANK()

# %%
query = '''
select emp_id,emp_name,dept_id,salary,
RANK() OVER (PARTITION BY dept_id ORDER BY salary desc) as rnk,
DENSE_RANK() OVER (PARTITION BY dept_id ORDER BY salary DESC) as dense_rank
from employees ;
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# CTE = common table expression

# %% [markdown]
# CTE is a temporary result which is define using the WITH keyword

# %%
With cte_name as(
    select.....
)
select * from cte_name;

# %% [markdown]
# Get employees with salary above average

# %%
query = '''
With avg_salary as (
  select avg(salary) as avg_sal from employees
)
select emp_id,emp_name,salary
from employees ,avg_salary
where employees.salary > avg_salary.avg_sal
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#    emp_id emp_name  salary
# 0       2     Mohd    6000
# 1       5    Ahmed    6500
# 2       7     John    7000
# 3       8    Priya    5800
# 4       9    David    6200
# 5      12   Sophia    5900
# 6      13   Robert    6700
# 7      15   Daniel    7100

# %% [markdown]
# Show department with more than 2 employee

# %%
query = '''
With emp_count as (
  select dept_id,count(*) as emp_total
  from employees
  group by dept_id
)
select * from emp_count
where emp_total > 1;
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#    dept_id  emp_total
# 0      102          2
# 1      103          2
# 2      106          2
# 3      108          2

# %% [markdown]
# Find all employee assigned to "Project Alfa" using CTE

# %%
query = '''
With project_alpha_emp as (
    select ep.emp_id
    from employee_projects ep
    JOIN projects p ON ep.project_id = p.project_id
    where p.project_name = 'Project Alpha'
)
select e.emp_id,e.emp_name
from employees e
Join project_alpha_emp pa ON e.emp_id = pa.emp_id

'''

df = pd.read_sql_query(query, conn)
df
# Out:
#    emp_id emp_name
# 0       1      Ali
# 1       2     Mohd
# 2       7     John
# 3       9    David
# 4      12   Sophia

# %% [markdown]
# get each departments avg salary ,then list employee above it with cte

# %%
query = '''
With dept_avg as (
  select dept_id ,avg(salary) as avg_sal
  from employees
  group by dept_id
)
select e.emp_id,e.emp_name,e.salary,d.avg_sal
from employees e
JOIN dept_avg d ON e.dept_id =d.dept_id
where e.salary > d.avg_sal;
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#    emp_id emp_name  salary  avg_sal
# 0       7     John    7000   6200.0
# 1       9    David    6200   6100.0
# 2      13   Robert    6700   6100.0
# 3      15   Daniel    7100   6450.0

# %% [markdown]
# list employee who are working on more than 1 project

# %%
query = '''
with emp_project_count as (
  select emp_id,count(*) as project_count
  from employee_projects
  group by emp_id
)
select e.emp_id,e.emp_name,project_count
from employees e
JOIN emp_project_count ep ON e.emp_id = ep.emp_id
where project_count >1;
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#     emp_id emp_name  project_count
# 0        1      Ali              2
# 1        2     Mohd              2
# 2        3    Rahul              2
# 3        4      Raj              2
# 4        5    Ahmed              2
# 5        6    Sneha              2
# 6        7     John              2
# 7        8    Priya              2
# 8        9    David              2
# 9       10   Anjali              2
# 10      11  Michael              2
# 11      12   Sophia              2
# 12      13   Robert              2
# 13      15   Daniel              2

# %% [markdown]
# Find the higest paid employees in each department

# %%
query = '''
With ranked_salary as (
  select emp_id,emp_name,dept_id,salary,
  Rank() OVER (PARTITION BY dept_id ORDER BY salary desc) as rnk
  from employees
)
select * from ranked_salary
where rnk=1;
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#     emp_id emp_name  dept_id  salary  rnk
# 0        4      Raj      NaN    4500    1
# 1        1      Ali    101.0    5000    1
# 2        9    David    102.0    6200    1
# 3       13   Robert    103.0    6700    1
# 4        6    Sneha    104.0    5200    1
# 5        5    Ahmed    105.0    6500    1
# 6        7     John    106.0    7000    1
# 7       12   Sophia    107.0    5900    1
# 8       15   Daniel    108.0    7100    1
# 9       10   Anjali    109.0    4800    1
# 10      11  Michael    110.0    5300    1

# %% [markdown]
# List department where all employee have salary > 5000

# %%
query = '''
with dept_emp as (
  select dept_id,salary as min_sal
  from employees
  group by dept_id

)
select d.dept_id,dept_name
from department d
JOIN dept_emp dm ON d.dept_id = dm.dept_id
where dm.min_sal>5000;
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#    dept_id               dept_name
# 0      102                      IT
# 1      103                 Finance
# 2      104                   Sales
# 3      105                 Finance
# 4      106               Marketing
# 5      107              Operations
# 6      108  Research & Development
# 7      110       Quality Assurance

# %% [markdown]
# query = '''
# select dept_id
# from employees
# Group by dept_id
# HAVING MIN(salary) > 5000
# '''
#
# df = pd.read_sql_query(query, conn)
# df

# %%
query = '''
select dept_id
from employees
Group by dept_id
HAVING MIN(salary) > 5000
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#    dept_id
# 0      102
# 1      103
# 2      104
# 3      105
# 4      106
# 5      107
# 6      108
# 7      110

# %% [markdown]
# List employee not assigned to any project

# %%
query = '''
With assigned_emp as (
  select distinct emp_id from employee_projects
)

select e.emp_id,e.emp_name
from employees e
JOIN assigned_emp a ON e.emp_id =a.emp_id
where a.emp_id IS NULL;
'''

df = pd.read_sql_query(query, conn)
df
# Out:
# Empty DataFrame
# Columns: [emp_id, emp_name]
# Index: []

# %% [markdown]
# List employee who have the maximum salary in their departments

# %%
query = '''
With dept_max_sal as (
  select dept_id,MAX(salary) as max_salary
  from employees
  group by dept_id
)
select e.emp_name,e.salary,d.dept_name
from employees e
JOIN dept_max_sal dms ON e.dept_id =dms.dept_id  and e.salary =dms.max_salary
JOIN department d ON e.dept_id =d.dept_id
'''

df = pd.read_sql_query(query, conn)
df
# Out:
#   emp_name  salary               dept_name
# 0      Ali    5000                      HR
# 1    Ahmed    6500                 Finance
# 2    Sneha    5200                   Sales
# 3     John    7000               Marketing
# 4    David    6200                      IT
# 5   Anjali    4800        Customer Support
# 6  Michael    5300       Quality Assurance
# 7   Sophia    5900              Operations
# 8   Robert    6700                 Finance
# 9   Daniel    7100  Research & Development

# %% [markdown]
# list employee who earn more than average salary of all employee

# %% [markdown]
# IF /NULL IF

# %% [markdown]
# If (condition)
# it return one value if the condition is true and another value if false

# %% [markdown]
#   /NULL IF
# return NULL if emp1=emp2 ,otherwise return emp1

# %% [markdown]
# Show employee name and flag 'Yes' if their salary is grater than 5000 else 'no'

# %%
query = '''
select emp_name,
    IF(salary > 5000,'Yes','NO') as high_paid
from employees
'''

df = pd.read_sql_query(query, conn)
df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such function: IF
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-50-011198a225e5> in <cell line: 0>()
#       5 '''
#       6
# ----> 7 df = pd.read_sql_query(query, conn)
#       8 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql '
# select emp_name,
#     IF(salary > 5000,'Yes','NO') as high_paid
# from employees
# ': no such function: IF

# %% [markdown]
# Replace 0 project hours with NULL using NULLIF()

# %%
query = '''
select emp_id,project_id,
NULLIF(hours_worked,0) as valid_hours
from employee_projects;
'''

df = pd.read_sql_query(query, conn)
df

# %% [markdown]
# Show employee with 'Same' or 'Differnt' label depending on their dept_id equals 103

# %%
query = '''
select emp_name,
IF(dept_id = 103,'Same','Differnt') as dept_check
from employees;
'''

df = pd.read_sql_query(query, conn)
df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such function: IF
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-52-55799df2f72d> in <cell line: 0>()
#       5 '''
#       6
# ----> 7 df = pd.read_sql_query(query, conn)
#       8 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql '
# select emp_name,
# IF(dept_id = 103,'Same','Differnt') as dept_check
# from employees;
# ': no such function: IF

# %% [markdown]
# Avoid showing duplicate dept_id 103 by replacing it with null

# %%
query = '''
select emp_name,
NULLIF(dept_id ,103) as updated_dept
from employee
'''

df = pd.read_sql_query(query, conn)
df
